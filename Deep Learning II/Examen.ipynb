# %% [markdown]
# Dado que el entrenamiento de redes neuronales es una tarea  muy costosa, **se recomienda ejecutar el notebooks en [Google Colab](https://colab.research.google.com)**, por supuesto también se puede ejecutar en local.
#
# Al entrar en [Google Colab](https://colab.research.google.com) bastará con hacer click en `upload` y subir este notebook. No olvide luego descargarlo en `File->Download .ipynb`
#
# **El examen deberá ser entregado con las celdas ejecutadas, si alguna celda no está ejecutadas no se contará.**

# %% [markdown]
# El examen se divide en dos partes, con la puntuación que se indica a continuación. La puntuación máxima será 10.
#
# - [Actividad 1: Redes Densas](#actividad_1): 5 pts
#     - Correcta normalización: máximo de 0.25 pts
#     - [Cuestión 1](#1.1): 1.5 pt
#     - [Cuestión 2](#1.2): 1.5 pt
#     - [Cuestión 3](#1.3): 0.5 pts
#     - [Cuestión 4](#1.4): 0.25 pts
#     - [Cuestión 5](#1.5): 0.25 pts
#     - [Cuestión 6](#1.6): 0.25 pts
#     - [Cuestión 7](#1.7): 0.25 pts
#     - [Cuestión 8](#1.8): 0.25 pts
#
#
# - [Actividad 2: Redes Convolucionales](#actividad_2): 5 pts
#     - [Cuestión 1](#2.1): 2.5 pt
#     - [Cuestión 2](#2.2): 1 pt
#     - [Cuestión 3](#2.3): 0.5 pts
#     - [Cuestión 4](#2.4): 0.5 pts
#     - [Cuestión 5](#2.5): 0.5 pts

# %%
import tensorflow as tf
import keras
from keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)
keras.utils.set_random_seed(0)

# %% [markdown]
# <a name='actividad_1'></a>
# # Actividad 1: Redes Densas
#
# Para esta primera actividad vamos a utilizar el [California Housing Dataset](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset). Con el que trataremos de predecir el precio mediano de las viviendas en diferentes distritos de California.
#
# El precio de las viviendas es un valor continuo que está expresado en cientos de miles de dólares (por ejemplo, un valor de 2.5 significa $250,000). Por lo tanto, el problema es una `regresión`.
#
# **Features del dataset:**
# - MedInc: Ingreso mediano del distrito
# - HouseAge: Edad mediana de las casas
# - AveRooms: Promedio de habitaciones por vivienda
# - AveBedrms: Promedio de dormitorios por vivienda
# - Population: Población del distrito
# - AveOccup: Promedio de ocupantes por vivienda
# - Latitude: Latitud
# - Longitude: Longitud
#
#
# **Puntuación**:
#
# Normalizar las features correctamente (x_train, x_test): 0.25 pts , se pueden normalizar con el [Normalization layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Normalization) de Keras.
#
#
# - Correcta normalización: máximo de 0.25 pts
# - [Cuestión 1](#1.1): 1.5 pt
# - [Cuestión 2](#1.2): 1.5 pt
# - [Cuestión 3](#1.3): 0.5 pts
# - [Cuestión 4](#1.4): 0.25 pts
# - [Cuestión 5](#1.5): 0.25 pts
# - [Cuestión 6](#1.6): 0.25 pts
# - [Cuestión 7](#1.7): 0.25 pts
# - [Cuestión 8](#1.8): 0.25 pts

# %%
# Cargar el dataset
housing = fetch_california_housing(as_frame=True)
df = housing.frame

# Mostrar información básica
print(f"Tamaño del dataset: {df.shape}")
print(f"Rango de precios: ${df['MedHouseVal'].min():.1f}k - ${df['MedHouseVal'].max():.1f}k")
print("\nPrimeras 5 filas:")
df.head()
# Out:
# Tamaño del dataset: (20640, 9)
# Rango de precios: $0.1k - $5.0k
#
# Primeras 5 filas:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# separar features y target
y = df.pop('MedHouseVal').values
X = df.copy().values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)
print('Some prices: ', y_train[:5])
# Out:
# x_train, y_train shapes: (15480, 8) (15480,)
# x_test, y_test shapes: (5160, 8) (5160,)
# Some prices:  [3.813   3.293   1.854   5.00001 0.975  ]

# %%
## Si quiere, puede normalizar las features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


x_train_scaled = scaler.fit_transform(x_train)


x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# <a name='1.1'></a>
# ## Cuestión 1: Cree un modelo secuencial que contenga 4 capas ocultas(hidden layers), con más de 60 neuronas  por capa, sin regularización y obtenga los resultados.

# %%
# Codifique el modelo en esta celda
model = tf.keras.models.Sequential()

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1)  # salida para regresión
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilación del modelo
# Código aquí

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
model.fit(x_train,
          y_train,
          epochs=60,
          batch_size=32,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 134.5538 - mae: 5.2591 - val_loss: 2.2812 - val_mae: 1.2115
# Epoch 2/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6842 - mae: 1.3865 - val_loss: 1.1974 - val_mae: 0.8305
# Epoch 3/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7231 - mae: 1.1402 - val_loss: 1.3719 - val_mae: 0.9003
# Epoch 4/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5648 - mae: 1.0372 - val_loss: 8.1670 - val_mae: 1.7873
# Epoch 5/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8048 - mae: 1.1330 - val_loss: 17.2140 - val_mae: 2.9001
# Epoch 6/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6651 - mae: 1.8472 - val_loss: 2.2519 - val_mae: 1.0996
# Epoch 7/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1937 - mae: 0.8519 - val_loss: 0.9261 - val_mae: 0.7492
# Epoch 8/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.2034 - mae: 0.8110 - val_loss: 3.9920 - val_mae: 1.6064
# Epoch 9/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.2292 - mae: 0.8148 - val_loss: 7.3450 - val_mae: 2.4731
# Epoch 10/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9012 - mae: 1.1916 - val_loss: 0.9010 - val_mae: 0.7525
# Epoch 11/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9604 - mae: 0.7554 - val_loss: 0.9028 - val_mae: 0.6891
# Epoch 12/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9215 - mae: 0.7333 - val_loss: 1.2621 - val_mae: 0.7958
# Epoch 13/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0687 - mae: 0.7747 - val_loss: 0.8010 - val_mae: 0.6415
# Epoch 14/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1503 - mae: 0.7961 - val_loss: 2.5326 - val_mae: 1.3296
# Epoch 15/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9582 - mae: 0.7431 - val_loss: 0.8193 - val_mae: 0.6441
# Epoch 16/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8663 - mae: 0.6990 - val_loss: 1.9178 - val_mae: 1.0856
# Epoch 17/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8485 - mae: 0.6998 - val_loss: 1.4515 - val_mae: 0.8671
# Epoch 18/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9913 - mae: 0.7572 - val_loss: 0.8666 - val_mae: 0.6927
# Epoch 19/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7732 - mae: 0.6716 - val_loss: 4.0367 - val_mae: 1.2788
# Epoch 20/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0420 - mae: 0.7587 - val_loss: 0.7942 - val_mae: 0.7352
# Epoch 21/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6964 - mae: 0.6327 - val_loss: 0.7481 - val_mae: 0.7041
# Epoch 22/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6926 - mae: 0.6255 - val_loss: 0.6240 - val_mae: 0.6276
# Epoch 23/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6622 - mae: 0.6078 - val_loss: 1.2062 - val_mae: 0.8998
# Epoch 24/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7022 - mae: 0.6292 - val_loss: 0.7525 - val_mae: 0.6256
# Epoch 25/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7885 - mae: 0.6635 - val_loss: 0.8565 - val_mae: 0.7574
# Epoch 26/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.
60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5219 - mae: 0.5349 - val_loss: 0.4690 - val_mae: 0.5275

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
test_metrics = dict(zip(model.metrics_names, results))
print('Test Metrics:', test_metrics)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4999 - mae: 0.5385
# Test Metrics: {'loss': 0.4842490553855896, 'compile_metrics': 0.5333328247070312}

# %% [markdown]
# <a name='1.2'></a>
# ## Cuestión 2: Utilice el mismo modelo de la cuestión anterior pero añadiendo al menos dos técnicas distinas de regularización. No es necesario reducir el `test loss`.
#
# Ejemplos de regularización: [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb)

# %%
# Compilación del modelo
# Código aquí
model.compile( optimizer='adam',
    loss='mse',
    metrics=['mae'])

# %%
batch_size= 32

# %%
model.fit(x_train,
          y_train,
          epochs=60,
          batch_size=batch_size,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5355 - mae: 0.5424 - val_loss: 0.4692 - val_mae: 0.5168
# Epoch 2/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5197 - mae: 0.5334 - val_loss: 0.5017 - val_mae: 0.5474
# Epoch 3/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5491 - mae: 0.5399 - val_loss: 0.4754 - val_mae: 0.5318
# Epoch 4/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5142 - mae: 0.5303 - val_loss: 0.4681 - val_mae: 0.5225
# Epoch 5/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5122 - mae: 0.5288 - val_loss: 0.4938 - val_mae: 0.5404
# Epoch 6/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5127 - mae: 0.5289 - val_loss: 0.4971 - val_mae: 0.5469
# Epoch 7/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5160 - mae: 0.5302 - val_loss: 0.4843 - val_mae: 0.5376
# Epoch 8/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5177 - mae: 0.5318 - val_loss: 0.4699 - val_mae: 0.5232
# Epoch 9/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5047 - mae: 0.5238 - val_loss: 0.4675 - val_mae: 0.5219
# Epoch 10/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5070 - mae: 0.5248 - val_loss: 0.4752 - val_mae: 0.5279
# Epoch 11/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5040 - mae: 0.5238 - val_loss: 0.4932 - val_mae: 0.5402
# Epoch 12/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5029 - mae: 0.5233 - val_loss: 0.4626 - val_mae: 0.5187
# Epoch 13/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4990 - mae: 0.5208 - val_loss: 0.5003 - val_mae: 0.5369
# Epoch 14/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5093 - mae: 0.5277 - val_loss: 0.4903 - val_mae: 0.5437
# Epoch 15/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5015 - mae: 0.5222 - val_loss: 0.4471 - val_mae: 0.4993
# Epoch 16/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5001 - mae: 0.5203 - val_loss: 0.4852 - val_mae: 0.5148
# Epoch 17/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5121 - mae: 0.5284 - val_loss: 0.4521 - val_mae: 0.4957
# Epoch 18/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5078 - mae: 0.5209 - val_loss: 0.4561 - val_mae: 0.4958
# Epoch 19/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4921 - mae: 0.5151 - val_loss: 0.4468 - val_mae: 0.4949
# Epoch 20/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5059 - mae: 0.5241 - val_loss: 0.4493 - val_mae: 0.4971
# Epoch 21/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5025 - mae: 0.5219 - val_loss: 0.4480 - val_mae: 0.4987
# Epoch 22/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5045 - mae: 0.5214 - val_loss: 0.4502 - val_mae: 0.4963
# Epoch 23/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5004 - mae: 0.5208 - val_loss: 0.4567 - val_mae: 0.4948
# Epoch 24/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5057 - mae: 0.5228 - val_loss: 0.4441 - val_mae: 0.4959
# Epoch 25/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.
60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4882 - mae: 0.5128 - val_loss: 0.4545 - val_mae: 0.4962
# Epoch 60/60
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4853 - mae: 0.5096 - val_loss: 0.4581 - val_mae: 0.4961

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
test_metrics = dict(zip(model.metrics_names, results))
print('Test Metrics:', test_metrics)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4905 - mae: 0.5105
# Test Metrics: {'loss': 0.46965330839157104, 'compile_metrics': 0.5004305243492126}

# %% [markdown]
# <a name='1.3'></a>
# ## Cuestión 3: Utilice el mismo modelo de la cuestión anterior pero añadiendo un callback de early stopping.  No es necesario reducir el `test loss`.

# %%
model = tf.keras.models.Sequential()
# Código aquí
...
# Out:
# Ellipsis

# %%
# Compilación del modelo
# Código aquí
model.compile(...)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-644565160.py in <cell line: 0>()
#       1 # Compilación del modelo
#       2 # Código aquí
# ----> 3 model.compile(...)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/__init__.py in get(identifier)
#      96     if isinstance(obj, Optimizer):
#      97         return obj
# ---> 98     raise ValueError(f"Could not interpret optimizer identifier: {identifier}")
#      99
#     100
#
# ValueError: Could not interpret optimizer identifier: Ellipsis

# %%
## definir el early stopping callback
# Código aquí
...
model.fit(x_train,
          y_train,
          epochs=60,
          batch_size=32,
          validation_split=0.2,
          verbose=1,
          callbacks=[...]) # Código aquí

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
test_metrics = dict(zip(model.metrics_names, results))
print('Test Metrics:', test_metrics)

# %% [markdown]
# <a name='1.4'></a>
# ## Cuestión 4: ¿Podría haberse usado otra función de activación de la neurona de salida? En caso afirmativo especifíquela.

# %% [markdown]
# **Respuesta:** (Escriba: "No" o "Sí, [nombre de la función]")
#
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='1.5'></a>
# ## Cuestión 5:  ¿Qué es lo que una neurona calcula?
#
# **a)** Una función de activación seguida de una suma ponderada  de las entradas.
#
# **b)** Una suma ponderada  de las entradas seguida de una función de activación.
#
# **c)** Una función de pérdida, definida sobre el target.
#
# **d)** Ninguna  de las anteriores es correcta

# %% [markdown]
# (Escriba solo la letra: a, b, c o d)
#
# **Respuesta:**
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='1.6'></a>
# ## Cuestión 6:  ¿Cuál de estas funciones de activación no debería usarse en una capa oculta (hidden layer)?
#
# **a)** `sigmoid`
#
# **b)** `tanh`
#
# **c)** `relu`
#
# **d)** `linear`

# %% [markdown]
# **Respuesta:** (Escriba solo la letra: a, b, c o d)
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='1.7'></a>
# ## Cuestión 7:  ¿Cuál de estas técnicas es efectiva para combatir el overfitting en una red con varias capas ocultas? Ponga todas las que lo sean.
#
# **a)** Dropout
#
# **b)** Regularización L2.
#
# **c)** Aumentar el tamaño del test set.
#
# **d)** Aumentar el tamaño del validation set.
#
# **e)** Reducir el número de capas de la red.
#
# **f)** Data augmentation.

# %% [markdown]
# **Respuesta:** (Escriba las letras separadas por comas. Ejemplo: a, b, e)
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='1.8'></a>
# ## Cuestión 8:  Supongamos que queremos entrenar una red para un problema de clasificación de imágenes con las siguientes clases: {'perro','gato','persona'}. ¿Cuántas neuronas y que función de activación debería tener la capa de salida? ¿Qué función de pérdida (loss function) debería usarse?

# %% [markdown]
# **Respuesta:**
# - Número de neuronas:
# - Función de activación:
# - Loss function:
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='actividad_2'></a>
# # Actividad 2: Redes Convolucionales
#
# Vamos a usar el dataset [cifar-10](https://www.cs.toronto.edu/~kriz/cifar.html), que son 60000 imágenes de 32x32 a color  con 10 clases diferentes. Para realizar mejor la práctica puede consultar [Introduction_to_CNN.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/CNN/Introduction_to_CNN.ipynb).
#
#
#
# **Puntuación**:
#
# - [Cuestión 1](#2.1): 2.5 pt
# - [Cuestión 2](#2.2): 1 pt
# - [Cuestión 3](#2.3): 0.5 pts
# - [Cuestión 4](#2.4): 0.5 pts
# - [Cuestión 5](#2.5): 0.5 pts
#
# Puede normalizar las imágenes al principio o usar la capa [Rescaling](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Rescaling):
#
# ```python
# tf.keras.layers.experimental.preprocessing.Rescaling(
#     scale, offset=0.0, name=None, **kwargs
# )
# ```

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)

# %% [markdown]
# <a name='2.1'></a>
# ## Cuestión 1: Cree una red convolucional con la API funcional con al menos dos capas convolucionales y al menos dos capas de pooling. Debe obtener un `Test accuracy > 0.70`

# %%
inputs = tf.keras.Input(shape=..., name='input')
# reescaling = ...

# Convolution + pooling layers
...

# Flattening
...

# Fully-connected
outputs = layers.Dense(...)

model = keras.Model(inputs=..., outputs=...)

# %%
model.compile(
    optimizer='adam',
    loss=...,
    metrics=[...],
    )

# %%
# (Opcional) si quiere, puede definir un callback para early stopping
# early_stopping = ...

# %%
history = model.fit(x_train, y_train, epochs=25, batch_size=64,
                    validation_split=0.15)

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)

test_metrics = dict(zip(model.metrics_names, results))
for metric in model.metrics_names:
    print(f"test_{metric}: {test_metrics[metric]}")

# %% [markdown]
# <a name='2.2'></a>
# ## Cuestión 2: Cree el mismo  modelo de manera secuencial. No es necesario compilar ni entrenar el modelo

# %%
model_seq = tf.keras.models.Sequential()
# Código aquí
...

# %% [markdown]
# <a name='2.3'></a>
# ## Cuestión 3: Si tenenemos una  una imagen de entrada de 300 x 300 a color (RGB) y queremos usar una red densa. Si la primera capa oculta tiene 100 neuronas, ¿Cuántos parámetros tendrá esa capa (sin incluir el bias) ?

# %% [markdown]
# **Respuesta:** (Escriba solo el número)
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='2.4'></a>
# ## Cuestión 4   Ponga  las verdaderas ventajas de las redes convolucionales respecto a las densas
#
# **a)** Reducen el número total de parámetros, reduciendo así el overfitting.
#
# **b)** Permiten utilizar una misma 'función'  en varias localizaciones de la imagen de entrada, en lugar de aprender una función diferente para cada pixel.
#
# **c)** Permiten el uso del transfer learning.
#
# **d)** Generalmente son menos profundas, lo que facilita su entrenamiento.

# %% [markdown]
# **Respuesta:** (Escriba las letras separadas por comas. Ejemplo: a, b)
#
# **Justificación o aclaración (opcional):**

# %% [markdown]
# <a name='2.5'></a>
# ## Cuestión 5: Para el procesamiento de series temporales las redes convolucionales no son efectivas, habrá que usar redes recurrentes.
#
# - **Verdadero**
# - **Falso**

# %% [markdown]
# **Respuesta:** (Escriba: Verdadero o Falso)
#
# **Justificación o aclaración (opcional):**
